# %% [markdown]
# # Bayesian Statistical Inference: V
#
# *Davide Gerosa (Milano-Bicocca)*
#
# ##### Reading:
#
# - [Textbook](http://press.princeton.edu/titles/10159.html) Chapter 5.
# - [Sampler, Samplers, Everywhere...](http://mattpitkin.github.io/samplers-demo/pages/samplers-samplers-everywhere/) by Matt Pitkin.
#
# This course is based on previous work by many people. See [here]((https://github.com/dgerosa/astrostatistics_bicocca_2022/blob/main/README.md) for credits.

# %% [markdown]
# Make sure the python package `dynesty` is installed. If you're running this notebook through binder, things should just work...

# %% [markdown]
# ##  Practical Evidence Evaluation & Model Selection <a class="anchor" id="two"></a>
#
# We've discussed Bayesian parameter estimation algorithms in detail. But what about evidence evaluation and model comparison? We already have the AIC and BIC as proxies. Grid-based methods for integrating the likelihood $\times$ prior are far too crude.
#
# There are some further numerical techniques that we'll briefly discuss, before looking at examples of **Nested Sampling** algorithms to compute the Bayesian evidence.
#
# ### Savage-Dickey Density Ratio
#
# This is great for when we want to compare models that have nested parameters, e.g. (1) a model with just noise, and (2) a model with a signal and noise.
#
# We need to be able to identify a parameter in the signal model that acts as an amplitude, $A$, that can effectively switch the signal off when it is zero.
#
# Thus $p_1(d|n) = p_2(d|A=0,n)$.
#
#
# An example from my research field, gravitational-astronomy, is testing General Relativity. Suppose you want to test a theory which is more generic than GR (say the graviton has a non-zero mass, which implies a dispersion relation for the emitted waves), in that case GR is a special case ($m=0$) of the more generic theory.
#
#
# With MCMC sampling we can map out the full parameter posterior distribution of model (2). We need to make sure we get good mixing and exploration of the parameter $A$ so that we can reconstruct its posterior density at $A=0$.
#
# The Bayes factor of Model $2$ (signal and noise) versus Model $1$ (noise alone) can be computed using the **[Savage-Dickey Density Ratio](https://www.jstor.org/stable/2958475?casa_token=Dc8wjaKRj5UAAAAA%3A4IhKgqNXc4jpan6hRxW7tBpXTI4i2236BulPTRxj4FcivD988vqJw-N75Dtw7z4Lh3YtPsDIceS8NDtIXAIRIO1T227h9VYZ2prQpwb46WLBB0GGz8w&seq=1#metadata_info_tab_contents)** approximation,
#
# $$ \mathcal{B} = \frac{\mathcal{Z}_2}{\mathcal{Z}_1} = \frac{p(A=0)}{p(A=0|d,n)}$$
#
# which is the prior density at $A=0$ divided by the conditional posterior density at $A=0$. We can easily compute the latter by making a histogram of posterior samples in $A$ and reading off the normalized pdf at $A=0$.
#
#
# ### Product-space Sampling
#
# Product-space sampling sounds fancy, but is super easy. In this type of model comparison, we never explicitly try to compute the Bayesian evidence.
#
# - We run a big MCMC chain that includes all parameters of all models, in addition to a model indexing parameter, $n$.
# - We define distinct ranges for this parameter, such that in certain sampling ranges it will trigger one of the model likelihoods to be used, e.g. if $-0.5<n<0.5$ use the likelihood for model $1$.
# - After sampling sufficiently long, the MCMC chain will spend different amounts of time in differnt regions of $n$ in proportion to the Bayesian odds ratio.
# - Hence, the ratio of samples in model sub-ranges of $n$ gives the Bayesian odds ratio. Simple!
# - This is heavily used in gravitational-wave searches for Pulsar Timing arrays, see [https://arxiv.org/abs/1801.02617](https://arxiv.org/abs/1801.02617), [https://arxiv.org/abs/2009.04496](https://arxiv.org/abs/2009.04496), and [https://arxiv.org/abs/2006.04810](https://arxiv.org/abs/2006.04810).
# - Refs [here](https://rss.onlinelibrary.wiley.com/doi/abs/10.1111/j.2517-6161.1995.tb02042.x) and [here](https://amstat.tandfonline.com/doi/abs/10.1198/10618600152627924?casa_token=Kgpt2ZvdMrcAAAAA%3Al5JB7EitQ7MjPmxBObu2XJXocZCE1tI2-ZAceCwBjJOi2TRajF7SaxFcQjo1Nn5AF9q6vKhkxpBd&#.YEZH4F1KiLo).
#
# ### Thermodynamic Integration
#
# This technique is pretty fancy, and is derived from analogies with thermodynamics. It is used for exact calculation of the Bayesian evidence.
#
# - Many MCMC chains are launched in parallel. However, their likelihoods differ slightly in their "temperature", $T$. We actually use the inverse temperature $\beta=1/T$ when writing the math. The temperature of a chain is used to modify the likelihood as follows, where
#
# $$ p(d|\theta)_\beta = p(d|\theta)^\beta = p(d|\theta)^{1/T}.$$
#
# - Thus only the $T=0$ chain corresponds to the actual model likelhiood.
# - But the other temperature chains have the effect of taking higher and higher roots of the likelihood, smoothing it out and making it more similar to the original prior.
# - These high temperature chains explore the parameter volume well, communicate back to the $T=0$ chain, and improve MCMC mixing.
# - Crucially, we can also use them in evidence computation:
#
# $$ \ln\mathcal{Z} = \int_0^1 \langle \ln p(d|\theta)\rangle_\beta\, d\beta, $$
#
# where we take the mean log-likelihood of each $\beta$ chain, then sum these over all temperatures to get the log-evidence. Refs [here](https://www.jstor.org/stable/2676756?casa_token=nGU-oa0w6lQAAAAA%3A8UNqj0_rBP7aZ4vocZ_NzbxKhre4WvzhbNOs_TTI_FfexQmppcxQSlxaO5PCHPZNAw9fZUmy4rPeXLe_CVJgAD2AYR6qS8D6xQDicpc1R45ZhjEtOV4&seq=1#metadata_info_tab_contents), and [here](https://link.springer.com/content/pdf/10.1007/BF01406511.pdf).

# %% [markdown]
# ### Nested Sampling
#
# Nested sampling is a very different MCMC method from Metropolis-Hastings or even Gibbs approaches.
#
# - One starts with many points spread throughout the prior volume.
# - The points are ranked in terms of their likelihood.
# - The lowest ranked point is removed, and a higher likelihood point is randomly added.
# - This is repeated, until the cluster of points climbs up the likelihood surface, accumulating Bayesian evidence information along the way.
#
# The prior volume is defined as $dX = p(\theta)d^n\theta$ such that $X(\lambda) = \int_{p(d|\theta)>\lambda}p(\theta)d^n\theta$, where the integral is over the model parameter region that exceeds the iso-likelihood contour $p(d|\theta)=L(\theta)=\lambda$.
#
# This transforms the evidence integral into
#
# $$\mathcal{Z} = \int p(d|\theta)p(\theta)d^n\theta = \int_0^1 L(X)dX.$$
#
#
# Here is how the algorithm works:
#
#
# ![Screen%20Shot%202022-03-30%20at%2008.35.40.png](attachment:Screen%20Shot%202022-03-30%20at%2008.35.40.png)
#
# ([credits](https://en.wikipedia.org/wiki/Nested_sampling_algorithm))

# %% [markdown]
# This paper is a nice example from the field of cosmology: https://arxiv.org/abs/astro-ph/0508461
#
# ![Screen%20Shot%202022-03-29%20at%2017.44.04.png](attachment:Screen%20Shot%202022-03-29%20at%2017.44.04.png)

# %% [markdown]
# There are several popular packages that perform nested sampling, and not only do they all compute the Bayesian evidence but they also produce posterior samples as a by-product.
#
#
# By far the most historically well known is [`MultiNest`](https://github.com/rjw57/MultiNest) and its Python wrapper [`PyMultiNest`](https://johannesbuchner.github.io/PyMultiNest/). It used to be (and may still be) a bit of a pain to install though (there is C and Fortran involved). Refs [here](https://ui.adsabs.harvard.edu/abs/2004AIPC..735..395S/abstract), and [here](https://academic.oup.com/mnras/article/398/4/1601/981502?login=true).
#
#
# So while this is the big one, there seem to be other more pythonic implementations now on the market. Let's look at one in particular, which is used in my research field.
#
# ---

# %% [markdown]
# ### Dynesty <a class="anchor" id="twoa"></a>
#
# https://arxiv.org/abs/1904.02180
#
# ![](https://github.com/joshspeagle/dynesty/blob/master/docs/images/title.gif?raw=true)

# %% [markdown]
# This example comes from the [dynesty](https://arxiv.org/abs/1904.02180) ["crash course"](https://dynesty.readthedocs.io/en/latest/crashcourse.html). We define our likelihood to be a $3$D correlated multivariate Gaussian distribution, and our prior to be uniform in each dimension from $-10$ to $10$.

# %%
import dynesty
import numpy as np

# Define the dimensionality of our problem.
ndim = 3

# Define our 3-D correlated multivariate normal likelihood.
C = np.identity(ndim)  # set covariance to identity matrix
C[C==0] = 0.95  # set off-diagonal terms
Cinv = np.linalg.inv(C)  # define the inverse (i.e. the precision matrix)
lnorm = -0.5 * (np.log(2 * np.pi) * ndim +
                np.log(np.linalg.det(C)))  # ln(normalization)

def loglike(x):
    """The log-likelihood function."""

    return -0.5 * np.dot(x, np.dot(Cinv, x)) + lnorm

# Define our uniform prior.
def ptform(u):
    """Transforms samples `u` drawn from the unit cube to samples to those
    from our uniform prior within [-10., 10.) for each variable."""

    return 10. * (2. * u - 1.)

# %% [markdown]
# Run the sampler.

# %%
# "Static" nested sampling.
sampler = dynesty.NestedSampler(loglike, ptform, ndim)
sampler.run_nested()
sresults = sampler.results
# Out:
# 4656it [00:06, 704.18it/s, +500 | bound: 8 | nc: 1 | ncall: 23953 | eff(%): 21.984 | loglstar:   -inf < -0.302 <    inf | logz: -8.824 +/-  0.126 | dlogz:  0.001 >  0.509]

# %% [markdown]
# You've just estimated the Bayesian evidence and posterior. Plot the results. These figures will have an $x$-axis that is $-\ln X$ which is a bit confusing to think about to begin with, but remember that we are moving up the likelihood contours when going from left to right on the graphs.

# %%
from dynesty import plotting as dyplot

# Plot a summary of the run.
rfig, raxes = dyplot.runplot(sresults)

# %% [markdown]
# How to interpret this... (Figure from https://arxiv.org/abs/1904.02180)
#
# ![Screen%20Shot%202022-03-29%20at%2017.31.01.png](attachment:Screen%20Shot%202022-03-29%20at%2017.31.01.png)

# %% [markdown]
# Plot parameter traces and 1-D marginalized posteriors. On the left panels, you'll see that the live points started out scattereed across the prior volume, then move inwards as the sampler climbs the likelihood.

# %%
tfig, taxes = dyplot.traceplot(sresults)

# %% [markdown]
# Plot the 2-D marginalized posteriors using `dynesty` routines. (But you could also use `corner` if you wish).

# %%
cfig, caxes = dyplot.cornerplot(sresults)

# %% [markdown]
# `dynesty` also lets you access many other utilities and analysis outputs. See below.

# %%
from dynesty import utils as dyfunc


# Extract sampling results.
samples = sresults.samples  # samples
weights = np.exp(sresults.logwt - sresults.logz[-1])  # normalized weights


evidence = sresults.logz[-1] #evidence
print("Bayesian evidence", np.exp(evidence))

# Compute 10%-90% quantiles.
quantiles = [dyfunc.quantile(samps, [0.16, 0.84], weights=weights)
             for samps in samples.T]
print('68% parameter credible regions are:\n ' + str(quantiles) + '\n')

# Compute weighted mean and covariance.
mean, cov = dyfunc.mean_and_cov(samples, weights)
print('Mean and covariance of parameters are: ' + str(mean) + '\n' + str(cov))

# Resample weighted samples.
samples_equal = dyfunc.resample_equal(samples, weights)

# Generate a new set of results with statistical+sampling uncertainties.
results_sim = dyfunc.simulate_run(sresults)
# Out:
# Bayesian evidence 0.00014719508928226634
# 68% parameter credible regions are:
#  [[-1.0101397459907189, 0.9006549373469], [-1.0395714320966258, 0.8888431595649595], [-1.0308366692690294, 0.8971534305619706]]
#
# Mean and covariance of parameters are: [-0.06213404 -0.07232056 -0.06870724]
# [[0.94104009 0.89340982 0.89003499]
#  [0.89340982 0.93883745 0.89078463]
#  [0.89003499 0.89078463 0.93535089]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 25
#      22 samples_equal = dyfunc.resample_equal(samples, weights)
#      24 # Generate a new set of results with statistical+sampling uncertainties.
# ---> 25 results_sim = dyfunc.simulate_run(sresults)
#
# AttributeError: module 'dynesty.utils' has no attribute 'simulate_run'

# %% [markdown]
# If you want to plot your posterior samples using `corner` or another package, then access the *equally weighted samples*.

# %%
import corner
corner.corner(samples_equal);

# %% [markdown]
# The code even helpfully tells you what work you should be citing based on the run configurations that you used.

# %%
print(sampler.citations)
# Out:
# Code and Methods:
#  ================
# Speagle (2020): ui.adsabs.harvard.edu/abs/2020MNRAS.493.3132S
# Koposov et al. (2023): doi.org/10.5281/zenodo.3348367
#
# Nested Sampling:
# ===============
# Skilling (2004): ui.adsabs.harvard.edu/abs/2004AIPC..735..395S
# Skilling (2006): projecteuclid.org/euclid.ba/1340370944
#
#
# Bounding Method:
# ===============
# Feroz, Hobson & Bridges (2009): ui.adsabs.harvard.edu/abs/2009MNRAS.398.1601F
#
# Sampling Method:
# ===============

# %% [markdown]
# There is a lot to explore in the `dynesty` package. It is not a panacea, and there are some things you may have to tune, e.g. the **number of initialized live points**, and **the evidence tolerance**. Dig into these caveats in your own time for your own research problems.
#
# Additionally, it implements **dynamic nested sampling** that dynamically allocates live points to explore higher posterior regions better at the expense of increasing the relative evidence uncertainty. See https://dynesty.readthedocs.io/en/latest/dynamic.html.

# %%
## "Dynamic" nested sampling.

#dsampler = dynesty.DynamicNestedSampler(loglike, ptform, ndim)
#dsampler.run_nested()
#dresults = dsampler.results

# %% [markdown]
# ### Some harder examples...
#
# Have a look at some of these runs!
#
# https://dynesty.readthedocs.io/en/latest/examples.html

# %% [markdown]
# ###  UltraNest <a class="anchor" id="twob"></a>
#
# *Refs: MLFriends (Buchner, 2014; 2019) using UltraNest https://johannesbuchner.github.io/UltraNest/*
#
# If you want to explore another sampler for your research, I highly reccommend looking into UltraNest.
#
# This is a nice example from the [UltraNest's documentation](https://johannesbuchner.github.io/UltraNest/using-ultranest.html), which involves fitting a **spectral line feature**. There are many other tutorials on the documentation to dig into in your own time.
#
# To see how `UltraNest` works compared to standard MCMC algorithms, go [here](https://johannesbuchner.github.io/UltraNest/method.html#visualisation).

# %% [markdown]
# ### Take home message
#
#
# There is a ton more to explore in nested sampling, evidence evaluation, model comparison, and parameter estimation.
#
# Alas, we must move on. However, these hands-on tutorials using real packages gives you an idea of the rich array of resources you can use for your own research.
#
# Make sure you know what is going on under the hood, but remember we're physicists after all!

# %% [markdown]
# ## Time to get your hands dirty.  The transient Universe
#
#
# Let's go back to our previous example on the astrophysical transient.
#
#
# 8) Fit the same model from before with the same priors,  but this time use nested sampling.
#
# $y = b$, for $t<t_0$
#
# $y = b + A\exp[-\alpha(t-t_0)]$, for $t\geq t_0$
#
# Be careful with how you transform your parameter space into a unit hypercube for the nested sampling priors (I used `ppf` from `scipy.stats.uniform`, but there are other ways to do it)
#
# An appropriate check on whether you have done things correctly is that the posterior samples you get from the burst analysis here should give an equivalent corner plot to the MCMC you did earlier.
#
# 7) Another possible model that may explain the data is a Gaussian profile described by:
#
# $y = b + A\exp[-(t-t_0)^2 / 2\sigma_W^2]$
#
# Fit this model usign nested sampling and reasonable priors (this time is up to you to decide...)
#
# 9) Unlike MCMCs, nested sampling provides the Bayesian evidence. Compute the Bayesian evidence for this Gaussian model, and for the original burst model. Which model is the favored description of the data?

# %%
import numpy as np
import pylab as plt
plt.rcParams['figure.figsize'] = [8, 8]
plt.rcParams['font.size'] = 12
import emcee
import scipy.stats
import corner
import dynesty
from dynesty import utils as dyfunc
from dynesty import plotting as dyplot

# %% [markdown]
# [My solution](https://github.com/dgerosa/astrostatistics_bicocca_2022/blob/main/solutions/S10_transient2.ipynb)

# %%
data= np.load('../solutions/transient.npy')

# %%
t,y,yerr=data.T
plt.errorbar(t,y,yerr=yerr,fmt='o')
plt.xlabel("time")
plt.ylabel("flux");

# %%
def burst(theta,t):
    A,b,t0,alpha=theta 
    return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))


def gprofile(theta,t):
    A,b,t0,sigmaW=theta     
    return b+A*np.exp(-(((t-t0)/sigmaW)**2 ) / 2)


t0min,t0max = 0,100
Amin,Amax=0,50
bmin,bmax=0,50
alphamin,alphamax=np.exp(-5),np.exp(5)
sigmaWmin,sigmaWmax=np.exp(-2),np.exp(2)

# %%
# Define the dimensionality of our problem.
ndim = 4

def loglike(theta, data, model):
    x, y, sigma_y = data.T
    if model =='burst':
        y_fit = burst(theta, x)
    elif model == 'gprofile':
        y_fit = gprofile(theta, x)

    # Note I'm not tracking the normalization here! 
    # Ok because here I only care about the ratio between two evidences, not the evidence itself
    return -0.5 * np.sum((y-y_fit)**2 / sigma_y**2 ) 


def ptform(u,model):
    """Transforms the uniform random variables `u ~ Unif[0., 1.)`
    to the parameters of interest."""

    x = np.array(u)  # copy u

    x[0] = scipy.stats.uniform(loc=Amin,scale=Amax-Amin).ppf(u[0])
    x[1] = scipy.stats.uniform(loc=bmin,scale=bmax-bmin).ppf(u[1])
    x[2] = scipy.stats.uniform(loc=t0min,scale=t0max-t0min).ppf(u[2])
   
    if model =='burst':
        x[3] = scipy.stats.loguniform.ppf(u[3],alphamin,alphamax)
    elif model =='gprofile':
        x[3] = scipy.stats.loguniform.ppf(u[3],sigmaWmin,sigmaWmax)
        #x[3] = scipy.stats.uniform(loc=sigmaWmin,scale=sigmaWmax-sigmaWmin).ppf(u[3])

    return x

# %%
# "Static" nested sampling.
sampler = dynesty.NestedSampler(loglike, ptform, ndim,logl_args=[data,'burst'],ptform_args=['burst'],nlive=100)
sampler.run_nested()
sresults = sampler.results
# Out:
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 348it [00:12,  6.04it/s, bound: 0 | nc: 106 | ncall: 3476 | eff(%): 10.012 | loglstar:   -inf < -156.280 <    inf | logz: -164.802 +/-  0.281 | dlogz: 89.741 >  0.109]    /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 350it [00:12,  6.83it/s, bound: 1 | nc: 8 | ncall: 3509 | eff(%):  9.974 | loglstar:   -inf < -154.854 <    inf | logz: -162.819 +/-  0.268 | dlogz: 86.613 >  0.109]  /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 381it [00:13, 33.10it/s, bound: 2 | nc: 4 | ncall: 3652 | eff(%): 10.433 | loglstar:   -inf < -130.833 <    inf | logz: -138.415 +/-  0.265 | dlogz: 61.522 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 385it [00:13, 22.38it/s, bound: 2 | nc: 42 | ncall: 3750 | eff(%): 10.267 | loglstar:   -inf < -129.425 <    inf | logz: -136.753 +/-  0.257 | dlogz: 59.680 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 389it [00:14, 14.81it/s, bound: 3 | nc: 6 | ncall: 3857 | eff(%): 10.086 | loglstar:   -inf < -127.456 <    inf | logz: -135.352 +/-  0.257 | dlogz: 58.357 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 392it [00:14, 11.16it/s, bound: 4 | nc: 2 | ncall: 3960 | eff(%):  9.899 | loglstar:   -inf < -126.258 <    inf | logz: -133.827 +/-  0.260 | dlogz: 56.767 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 404it [00:15, 16.91it/s, bound: 4 | nc: 12 | ncall: 4090 | eff(%):  9.878 | loglstar:   -inf < -121.592 <    inf | logz: -129.281 +/-  0.261 | dlogz: 52.111 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 412it [00:16, 13.58it/s, bound: 5 | nc: 11 | ncall: 4227 | eff(%):  9.747 | loglstar:   -inf < -118.354 <    inf | logz: -125.976 +/-  0.259 | dlogz: 48.582 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 414it [00:16, 12.75it/s, bound: 6 | nc: 8 | ncall: 4259 | eff(%):  9.721 | loglstar:   -inf < -117.817 <    inf | logz: -125.284 +/-  0.258 | dlogz: 47.856 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 418it [00:16, 10.41it/s, bound: 6 | nc: 13 | ncall: 4373 | eff(%):  9.559 | loglstar:   -inf < -117.009 <    inf | logz: -124.306 +/-  0.254 | dlogz: 46.758 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 423it [00:18,  6.05it/s, bound: 8 | nc: 21 | ncall: 4666 | eff(%):  9.066 | loglstar:   -inf < -114.788 <    inf | logz: -122.664 +/-  0.261 | dlogz: 45.300 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 426it [00:18,  7.54it/s, bound: 9 | nc: 30 | ncall: 4707 | eff(%):  9.050 | loglstar:   -inf < -113.658 <    inf | logz: -121.661 +/-  0.260 | dlogz: 44.150 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 464it [00:18, 42.97it/s, bound: 10 | nc: 5 | ncall: 4855 | eff(%):  9.557 | loglstar:   -inf < -103.408 <    inf | logz: -110.553 +/-  0.249 | dlogz: 32.430 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 470it [00:19, 25.29it/s, bound: 10 | nc: 40 | ncall: 4986 | eff(%):  9.426 | loglstar:   -inf < -102.237 <    inf | logz: -109.706 +/-  0.250 | dlogz: 31.545 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 483it [00:20, 23.22it/s, bound: 11 | nc: 2 | ncall: 5141 | eff(%):  9.395 | loglstar:   -inf < -99.579 <    inf | logz: -107.350 +/-  0.258 | dlogz: 29.111 >  0.109]  /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 492it [00:20, 16.84it/s, bound: 12 | nc: 22 | ncall: 5281 | eff(%):  9.316 | loglstar:   -inf < -96.379 <    inf | logz: -105.046 +/-  0.271 | dlogz: 26.928 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 501it [00:21, 18.68it/s, bound: 13 | nc: 17 | ncall: 5387 | eff(%):  9.300 | loglstar:   -inf < -94.963 <    inf | logz: -102.797 +/-  0.266 | dlogz: 24.361 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 509it [00:21, 20.37it/s, bound: 14 | nc: 5 | ncall: 5452 | eff(%):  9.336 | loglstar:   -inf < -93.772 <    inf | logz: -101.422 +/-  0.262 | dlogz: 22.858 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 518it [00:22, 18.74it/s, bound: 14 | nc: 17 | ncall: 5587 | eff(%):  9.272 | loglstar:   -inf < -92.574 <    inf | logz: -100.273 +/-  0.259 | dlogz: 21.616 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 521it [00:22, 13.08it/s, bound: 15 | nc: 2 | ncall: 5658 | eff(%):  9.208 | loglstar:   -inf < -92.420 <    inf | logz: -99.929 +/-  0.258 | dlogz: 21.215 >  0.109]  /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 523it [00:22, 11.67it/s, bound: 15 | nc: 3 | ncall: 5720 | eff(%):  9.143 | loglstar:   -inf < -92.157 <    inf | logz: -99.721 +/-  0.258 | dlogz: 20.987 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 528it [00:23, 12.80it/s, bound: 16 | nc: 19 | ncall: 5800 | eff(%):  9.103 | loglstar:   -inf < -91.618 <    inf | logz: -99.154 +/-  0.258 | dlogz: 20.366 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 540it [00:23, 19.69it/s, bound: 17 | nc: 8 | ncall: 5902 | eff(%):  9.149 | loglstar:   -inf < -90.537 <    inf | logz: -98.072 +/-  0.256 | dlogz: 19.150 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 544it [00:23, 20.34it/s, bound: 17 | nc: 30 | ncall: 5951 | eff(%):  9.141 | loglstar:   -inf < -90.024 <    inf | logz: -97.724 +/-  0.256 | dlogz: 18.766 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 557it [00:24, 32.27it/s, bound: 17 | nc: 3 | ncall: 6033 | eff(%):  9.233 | loglstar:   -inf < -89.390 <    inf | logz: -96.684 +/-  0.255 | dlogz: 17.566 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 565it [00:24, 27.50it/s, bound: 18 | nc: 13 | ncall: 6108 | eff(%):  9.250 | loglstar:   -inf < -89.060 <    inf | logz: -96.280 +/-  0.253 | dlogz: 17.071 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 568it [00:24, 17.69it/s, bound: 18 | nc: 33 | ncall: 6201 | eff(%):  9.160 | loglstar:   -inf < -88.986 <    inf | logz: -96.137 +/-  0.252 | dlogz: 16.896 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 575it [00:25, 21.73it/s, bound: 19 | nc: 14 | ncall: 6253 | eff(%):  9.196 | loglstar:   -inf < -88.670 <    inf | logz: -95.841 +/-  0.251 | dlogz: 16.528 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 582it [00:25, 16.94it/s, bound: 20 | nc: 13 | ncall: 6352 | eff(%):  9.162 | loglstar:   -inf < -88.471 <    inf | logz: -95.564 +/-  0.250 | dlogz: 16.175 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 599it [00:26, 28.31it/s, bound: 20 | nc: 6 | ncall: 6497 | eff(%):  9.220 | loglstar:   -inf < -88.147 <    inf | logz: -95.047 +/-  0.248 | dlogz: 15.477 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 606it [00:26, 20.45it/s, bound: 21 | nc: 19 | ncall: 6598 | eff(%):  9.185 | loglstar:   -inf < -87.975 <    inf | logz: -94.875 +/-  0.247 | dlogz: 28.185 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 609it [00:27,  8.53it/s, bound: 23 | nc: 188 | ncall: 6803 | eff(%):  8.952 | loglstar:   -inf < -87.955 <    inf | logz: -94.806 +/-  0.246 | dlogz: 28.085 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 618it [00:27, 14.67it/s, bound: 23 | nc: 7 | ncall: 6904 | eff(%):  8.951 | loglstar:   -inf < -87.814 <    inf | logz: -94.619 +/-  0.246 | dlogz: 27.805 >  0.109]  /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 621it [00:28, 12.76it/s, bound: 24 | nc: 7 | ncall: 6954 | eff(%):  8.930 | loglstar:   -inf < -87.768 <    inf | logz: -94.563 +/-  0.245 | dlogz: 27.718 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 641it [00:28, 23.36it/s, bound: 24 | nc: 11 | ncall: 7093 | eff(%):  9.037 | loglstar:   -inf < -87.533 <    inf | logz: -94.235 +/-  0.244 | dlogz: 27.186 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 649it [00:29, 14.65it/s, bound: 26 | nc: 11 | ncall: 7298 | eff(%):  8.893 | loglstar:   -inf < -87.484 <    inf | logz: -94.131 +/-  0.243 | dlogz: 27.001 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 654it [00:31,  6.63it/s, bound: 28 | nc: 2 | ncall: 7677 | eff(%):  8.519 | loglstar:   -inf < -87.390 <    inf | logz: -94.071 +/-  0.243 | dlogz: 26.891 >  0.109]  /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 658it [00:31,  7.39it/s, bound: 29 | nc: 34 | ncall: 7781 | eff(%):  8.456 | loglstar:   -inf < -87.361 <    inf | logz: -94.024 +/-  0.243 | dlogz: 34.699 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 667it [00:33,  8.01it/s, bound: 31 | nc: 3 | ncall: 8132 | eff(%):  8.202 | loglstar:   -inf < -87.305 <    inf | logz: -93.930 +/-  0.242 | dlogz: 34.514 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 675it [00:33, 12.70it/s, bound: 32 | nc: 31 | ncall: 8226 | eff(%):  8.206 | loglstar:   -inf < -87.287 <    inf | logz: -93.857 +/-  0.242 | dlogz: 34.359 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 678it [00:34,  9.13it/s, bound: 33 | nc: 30 | ncall: 8354 | eff(%):  8.116 | loglstar:   -inf < -87.261 <    inf | logz: -93.831 +/-  0.242 | dlogz: 34.304 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 680it [00:34,  7.63it/s, bound: 33 | nc: 45 | ncall: 8434 | eff(%):  8.063 | loglstar:   -inf < -87.255 <    inf | logz: -93.815 +/-  0.241 | dlogz: 34.267 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 685it [00:35,  6.34it/s, bound: 35 | nc: 29 | ncall: 8663 | eff(%):  7.907 | loglstar:   -inf < -87.243 <    inf | logz: -93.776 +/-  0.241 | dlogz: 34.178 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 687it [00:36,  6.93it/s, bound: 35 | nc: 40 | ncall: 8717 | eff(%):  7.881 | loglstar:   -inf < -87.235 <    inf | logz: -93.761 +/-  0.241 | dlogz: 34.143 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 690it [00:36,  8.07it/s, bound: 36 | nc: 25 | ncall: 8765 | eff(%):  7.872 | loglstar:   -inf < -87.218 <    inf | logz: -93.739 +/-  0.241 | dlogz: 34.091 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 692it [00:36,  7.89it/s, bound: 36 | nc: 4 | ncall: 8837 | eff(%):  7.831 | loglstar:   -inf < -87.209 <    inf | logz: -93.725 +/-  0.241 | dlogz: 34.057 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 694it [00:37,  4.37it/s, bound: 38 | nc: 30 | ncall: 9058 | eff(%):  7.662 | loglstar:   -inf < -87.207 <    inf | logz: -93.712 +/-  0.241 | dlogz: 34.024 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 698it [00:38,  5.74it/s, bound: 38 | nc: 56 | ncall: 9190 | eff(%):  7.595 | loglstar:   -inf < -87.200 <    inf | logz: -93.686 +/-  0.241 | dlogz: 33.957 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 700it [00:39,  3.10it/s, bound: 40 | nc: 99 | ncall: 9489 | eff(%):  7.377 | loglstar:   -inf < -87.191 <    inf | logz: -93.674 +/-  0.241 | dlogz: 33.925 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 701it [00:39,  3.31it/s, bound: 41 | nc: 42 | ncall: 9531 | eff(%):  7.355 | loglstar:   -inf < -87.191 <    inf | logz: -93.667 +/-  0.240 | dlogz: 33.909 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 702it [00:39,  3.67it/s, bound: 41 | nc: 46 | ncall: 9577 | eff(%):  7.330 | loglstar:   -inf < -87.187 <    inf | logz: -93.661 +/-  0.240 | dlogz: 33.893 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 703it [00:40,  3.18it/s, bound: 42 | nc: 83 | ncall: 9660 | eff(%):  7.277 | loglstar:   -inf < -87.183 <    inf | logz: -93.656 +/-  0.240 | dlogz: 33.877 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 712it [00:40, 11.24it/s, bound: 42 | nc: 19 | ncall: 9798 | eff(%):  7.267 | loglstar:   -inf < -87.156 <    inf | logz: -93.605 +/-  0.240 | dlogz: 33.737 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 718it [00:41, 10.45it/s, bound: 43 | nc: 7 | ncall: 9927 | eff(%):  7.233 | loglstar:   -inf < -87.140 <    inf | logz: -93.575 +/-  0.240 | dlogz: 33.646 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 720it [00:41,  6.50it/s, bound: 44 | nc: 92 | ncall: 10063 | eff(%):  7.155 | loglstar:   -inf < -87.136 <    inf | logz: -93.565 +/-  0.240 | dlogz: 33.616 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 723it [00:42,  6.39it/s, bound: 45 | nc: 54 | ncall: 10195 | eff(%):  7.092 | loglstar:   -inf < -87.132 <    inf | logz: -93.551 +/-  0.240 | dlogz: 33.572 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 725it [00:43,  4.97it/s, bound: 46 | nc: 125 | ncall: 10336 | eff(%):  7.014 | loglstar:   -inf < -87.130 <    inf | logz: -93.542 +/-  0.240 | dlogz: 33.543 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 728it [00:43,  4.44it/s, bound: 47 | nc: 74 | ncall: 10543 | eff(%):  6.905 | loglstar:   -inf < -87.125 <    inf | logz: -93.529 +/-  0.239 | dlogz: 33.500 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 730it [00:44,  5.12it/s, bound: 48 | nc: 47 | ncall: 10596 | eff(%):  6.889 | loglstar:   -inf < -87.124 <    inf | logz: -93.521 +/-  0.239 | dlogz: 33.472 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 731it [00:44,  4.52it/s, bound: 48 | nc: 90 | ncall: 10686 | eff(%):  6.841 | loglstar:   -inf < -87.124 <    inf | logz: -93.516 +/-  0.239 | dlogz: 33.457 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 735it [00:44,  7.66it/s, bound: 49 | nc: 17 | ncall: 10748 | eff(%):  6.838 | loglstar:   -inf < -87.120 <    inf | logz: -93.500 +/-  0.239 | dlogz: 33.401 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 737it [00:45,  5.72it/s, bound: 50 | nc: 52 | ncall: 10870 | eff(%):  6.780 | loglstar:   -inf < -87.120 <    inf | logz: -93.493 +/-  0.239 | dlogz: 33.374 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 745it [00:45, 11.90it/s, bound: 50 | nc: 24 | ncall: 10995 | eff(%):  6.776 | loglstar:   -inf < -87.106 <    inf | logz: -93.464 +/-  0.239 | dlogz: 33.265 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 747it [00:46,  4.52it/s, bound: 52 | nc: 38 | ncall: 11270 | eff(%):  6.628 | loglstar:   -inf < -87.102 <    inf | logz: -93.457 +/-  0.239 | dlogz: 33.238 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 751it [00:47,  4.97it/s, bound: 53 | nc: 39 | ncall: 11451 | eff(%):  6.558 | loglstar:   -inf < -87.100 <    inf | logz: -93.444 +/-  0.239 | dlogz: 33.185 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 753it [00:47,  5.92it/s, bound: 54 | nc: 29 | ncall: 11486 | eff(%):  6.556 | loglstar:   -inf < -87.099 <    inf | logz: -93.437 +/-  0.239 | dlogz: 33.158 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 756it [00:48,  6.26it/s, bound: 54 | nc: 57 | ncall: 11592 | eff(%):  6.522 | loglstar:   -inf < -87.098 <    inf | logz: -93.428 +/-  0.239 | dlogz: 33.119 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 761it [00:49,  8.27it/s, bound: 55 | nc: 17 | ncall: 11739 | eff(%):  6.483 | loglstar:   -inf < -87.094 <    inf | logz: -93.413 +/-  0.239 | dlogz: 33.054 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 765it [00:49,  8.30it/s, bound: 56 | nc: 58 | ncall: 11843 | eff(%):  6.460 | loglstar:   -inf < -87.093 <    inf | logz: -93.402 +/-  0.238 | dlogz: 33.003 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 767it [00:50,  5.71it/s, bound: 57 | nc: 18 | ncall: 11976 | eff(%):  6.404 | loglstar:   -inf < -87.092 <    inf | logz: -93.397 +/-  0.238 | dlogz: 32.978 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 769it [00:51,  3.44it/s, bound: 58 | nc: 125 | ncall: 12197 | eff(%):  6.305 | loglstar:   -inf < -87.092 <    inf | logz: -93.392 +/-  0.238 | dlogz: 32.953 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 772it [00:52,  3.13it/s, bound: 60 | nc: 54 | ncall: 12424 | eff(%):  6.214 | loglstar:   -inf < -87.091 <    inf | logz: -93.384 +/-  0.238 | dlogz: 32.915 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 773it [00:53,  1.96it/s, bound: 62 | nc: 240 | ncall: 12664 | eff(%):  6.104 | loglstar:   -inf < -87.091 <    inf | logz: -93.382 +/-  0.238 | dlogz: 32.903 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 775it [00:53,  2.59it/s, bound: 62 | nc: 49 | ncall: 12784 | eff(%):  6.062 | loglstar:   -inf < -87.090 <    inf | logz: -93.377 +/-  0.238 | dlogz: 32.878 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 776it [00:54,  3.00it/s, bound: 63 | nc: 35 | ncall: 12819 | eff(%):  6.054 | loglstar:   -inf < -87.090 <    inf | logz: -93.374 +/-  0.238 | dlogz: 32.866 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 781it [00:54,  7.23it/s, bound: 63 | nc: 5 | ncall: 12934 | eff(%):  6.038 | loglstar:   -inf < -87.065 <    inf | logz: -93.363 +/-  0.238 | dlogz: 32.804 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 784it [00:54,  7.12it/s, bound: 64 | nc: 30 | ncall: 13027 | eff(%):  6.018 | loglstar:   -inf < -86.952 <    inf | logz: -93.356 +/-  0.238 | dlogz: 32.768 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 785it [00:56,  1.83it/s, bound: 67 | nc: 452 | ncall: 13479 | eff(%):  5.824 | loglstar:   -inf < -86.947 <    inf | logz: -93.353 +/-  0.238 | dlogz: 32.755 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 786it [00:59,  1.03s/it, bound: 71 | nc: 566 | ncall: 14045 | eff(%):  5.596 | loglstar:   -inf < -86.945 <    inf | logz: -93.351 +/-  0.238 | dlogz: 32.743 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 787it [01:00,  1.11s/it, bound: 73 | nc: 291 | ncall: 14336 | eff(%):  5.490 | loglstar:   -inf < -86.928 <    inf | logz: -93.348 +/-  0.238 | dlogz: 32.730 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 789it [01:01,  1.17it/s, bound: 75 | nc: 102 | ncall: 14602 | eff(%):  5.403 | loglstar:   -inf < -86.900 <    inf | logz: -93.344 +/-  0.238 | dlogz: 32.706 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 790it [01:04,  1.22s/it, bound: 78 | nc: 486 | ncall: 15088 | eff(%):  5.236 | loglstar:   -inf < -86.894 <    inf | logz: -93.341 +/-  0.238 | dlogz: 32.693 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 792it [01:04,  1.26it/s, bound: 79 | nc: 119 | ncall: 15220 | eff(%):  5.204 | loglstar:   -inf < -86.809 <    inf | logz: -93.336 +/-  0.238 | dlogz: 32.669 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 793it [01:06,  1.12s/it, bound: 82 | nc: 507 | ncall: 15727 | eff(%):  5.042 | loglstar:   -inf < -86.760 <    inf | logz: -93.334 +/-  0.238 | dlogz: 32.656 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 795it [01:08,  1.01it/s, bound: 85 | nc: 28 | ncall: 16178 | eff(%):  4.914 | loglstar:   -inf < -86.725 <    inf | logz: -93.328 +/-  0.238 | dlogz: 32.631 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 797it [01:10,  1.12it/s, bound: 87 | nc: 312 | ncall: 16513 | eff(%):  4.827 | loglstar:   -inf < -86.677 <    inf | logz: -93.323 +/-  0.238 | dlogz: 32.606 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 801it [01:11,  1.86it/s, bound: 89 | nc: 77 | ncall: 16809 | eff(%):  4.765 | loglstar:   -inf < -86.580 <    inf | logz: -93.311 +/-  0.238 | dlogz: 32.555 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 802it [01:13,  1.21it/s, bound: 92 | nc: 428 | ncall: 17237 | eff(%):  4.653 | loglstar:   -inf < -86.521 <    inf | logz: -93.308 +/-  0.238 | dlogz: 32.542 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 803it [01:13,  1.37it/s, bound: 93 | nc: 69 | ncall: 17306 | eff(%):  4.640 | loglstar:   -inf < -86.493 <    inf | logz: -93.305 +/-  0.238 | dlogz: 32.529 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 804it [01:15,  1.22it/s, bound: 94 | nc: 274 | ncall: 17580 | eff(%):  4.573 | loglstar:   -inf < -86.472 <    inf | logz: -93.302 +/-  0.238 | dlogz: 32.516 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 805it [01:16,  1.13it/s, bound: 96 | nc: 238 | ncall: 17818 | eff(%):  4.518 | loglstar:   -inf < -86.269 <    inf | logz: -93.299 +/-  0.238 | dlogz: 32.503 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 807it [01:18,  1.06s/it, bound: 100 | nc: 72 | ncall: 18498 | eff(%):  4.363 | loglstar:   -inf < -86.083 <    inf | logz: -93.291 +/-  0.238 | dlogz: 32.475 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 810it [01:19,  2.14it/s, bound: 101 | nc: 13 | ncall: 18549 | eff(%):  4.367 | loglstar:   -inf < -86.018 <    inf | logz: -93.277 +/-  0.238 | dlogz: 32.433 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 811it [01:19,  2.53it/s, bound: 101 | nc: 43 | ncall: 18592 | eff(%):  4.362 | loglstar:   -inf < -86.011 <    inf | logz: -93.273 +/-  0.238 | dlogz: 32.418 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 812it [01:19,  2.34it/s, bound: 102 | nc: 120 | ncall: 18712 | eff(%):  4.339 | loglstar:   -inf < -85.907 <    inf | logz: -93.268 +/-  0.238 | dlogz: 32.404 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 815it [01:21,  2.37it/s, bound: 104 | nc: 139 | ncall: 18959 | eff(%):  4.299 | loglstar:   -inf < -85.803 <    inf | logz: -93.253 +/-  0.239 | dlogz: 32.359 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 819it [01:22,  3.27it/s, bound: 105 | nc: 89 | ncall: 19216 | eff(%):  4.262 | loglstar:   -inf < -85.699 <    inf | logz: -93.232 +/-  0.239 | dlogz: 32.299 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 822it [01:22,  3.86it/s, bound: 106 | nc: 115 | ncall: 19356 | eff(%):  4.247 | loglstar:   -inf < -85.396 <    inf | logz: -93.214 +/-  0.239 | dlogz: 32.252 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 825it [01:24,  3.09it/s, bound: 108 | nc: 18 | ncall: 19686 | eff(%):  4.191 | loglstar:   -inf < -85.027 <    inf | logz: -93.188 +/-  0.240 | dlogz: 32.199 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 826it [01:24,  2.62it/s, bound: 109 | nc: 126 | ncall: 19812 | eff(%):  4.169 | loglstar:   -inf < -85.017 <    inf | logz: -93.179 +/-  0.240 | dlogz: 32.180 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 827it [01:26,  1.74it/s, bound: 111 | nc: 288 | ncall: 20100 | eff(%):  4.114 | loglstar:   -inf < -84.921 <    inf | logz: -93.169 +/-  0.240 | dlogz: 32.161 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 828it [01:26,  1.66it/s, bound: 112 | nc: 149 | ncall: 20249 | eff(%):  4.089 | loglstar:   -inf < -84.666 <    inf | logz: -93.158 +/-  0.241 | dlogz: 32.141 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 829it [01:27,  1.57it/s, bound: 113 | nc: 160 | ncall: 20409 | eff(%):  4.062 | loglstar:   -inf < -84.664 <    inf | logz: -93.145 +/-  0.241 | dlogz: 32.119 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 830it [01:28,  1.74it/s, bound: 114 | nc: 93 | ncall: 20502 | eff(%):  4.048 | loglstar:   -inf < -84.642 <    inf | logz: -93.133 +/-  0.242 | dlogz: 32.097 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# ...
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 848it [01:45,  1.14s/it, bound: 141 | nc: 528 | ncall: 24504 | eff(%):  3.461 | loglstar:   -inf < -82.980 <    inf | logz: -92.706 +/-  0.258 | dlogz: 31.513 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 851it [01:53,  1.65s/it, bound: 152 | nc: 39 | ncall: 26261 | eff(%):  3.241 | loglstar:   -inf < -82.919 <    inf | logz: -92.601 +/-  0.262 | dlogz: 31.378 >  0.109]  /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 852it [01:54,  1.48s/it, bound: 154 | nc: 217 | ncall: 26478 | eff(%):  3.218 | loglstar:   -inf < -82.885 <    inf | logz: -92.568 +/-  0.263 | dlogz: 31.334 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 855it [01:58,  1.28s/it, bound: 160 | nc: 43 | ncall: 27494 | eff(%):  3.110 | loglstar:   -inf < -82.846 <    inf | logz: -92.473 +/-  0.266 | dlogz: 31.207 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 856it [01:58,  1.02s/it, bound: 161 | nc: 16 | ncall: 27510 | eff(%):  3.112 | loglstar:   -inf < -82.781 <    inf | logz: -92.442 +/-  0.267 | dlogz: 31.166 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 857it [01:59,  1.03it/s, bound: 162 | nc: 190 | ncall: 27700 | eff(%):  3.094 | loglstar:   -inf < -82.726 <    inf | logz: -92.411 +/-  0.268 | dlogz: 31.125 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 858it [01:59,  1.24it/s, bound: 162 | nc: 82 | ncall: 27782 | eff(%):  3.088 | loglstar:   -inf < -82.720 <    inf | logz: -92.380 +/-  0.269 | dlogz: 31.084 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 860it [02:00,  1.73it/s, bound: 163 | nc: 59 | ncall: 27900 | eff(%):  3.082 | loglstar:   -inf < -82.292 <    inf | logz: -92.305 +/-  0.271 | dlogz: 30.999 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 861it [02:02,  1.20it/s, bound: 165 | nc: 327 | ncall: 28227 | eff(%):  3.050 | loglstar:   -inf < -82.292 <    inf | logz: -92.263 +/-  0.272 | dlogz: 30.948 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 864it [02:04,  1.62it/s, bound: 168 | nc: 34 | ncall: 28683 | eff(%):  3.012 | loglstar:   -inf < -82.150 <    inf | logz: -92.145 +/-  0.275 | dlogz: 30.798 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 865it [02:04,  2.00it/s, bound: 169 | nc: 35 | ncall: 28718 | eff(%):  3.012 | loglstar:   -inf < -82.141 <    inf | logz: -92.105 +/-  0.276 | dlogz: 30.748 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 867it [02:04,  2.98it/s, bound: 169 | nc: 40 | ncall: 28808 | eff(%):  3.010 | loglstar:   -inf < -81.937 <    inf | logz: -92.027 +/-  0.278 | dlogz: 30.651 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 868it [02:05,  2.75it/s, bound: 170 | nc: 98 | ncall: 28906 | eff(%):  3.003 | loglstar:   -inf < -81.908 <    inf | logz: -91.984 +/-  0.279 | dlogz: 30.600 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 869it [02:05,  2.99it/s, bound: 170 | nc: 75 | ncall: 28981 | eff(%):  2.999 | loglstar:   -inf < -81.887 <    inf | logz: -91.943 +/-  0.280 | dlogz: 30.548 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 870it [02:05,  3.28it/s, bound: 171 | nc: 46 | ncall: 29027 | eff(%):  2.997 | loglstar:   -inf < -81.600 <    inf | logz: -91.897 +/-  0.281 | dlogz: 30.496 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 874it [02:06,  5.29it/s, bound: 171 | nc: 26 | ncall: 29148 | eff(%):  2.998 | loglstar:   -inf < -81.390 <    inf | logz: -91.692 +/-  0.285 | dlogz: 30.256 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 877it [02:06,  6.65it/s, bound: 172 | nc: 62 | ncall: 29219 | eff(%):  3.001 | loglstar:   -inf < -81.254 <    inf | logz: -91.548 +/-  0.288 | dlogz: 30.079 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 880it [02:07,  4.63it/s, bound: 173 | nc: 40 | ncall: 29451 | eff(%):  2.988 | loglstar:   -inf < -81.014 <    inf | logz: -91.399 +/-  0.290 | dlogz: 29.905 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 881it [02:08,  3.11it/s, bound: 175 | nc: 164 | ncall: 29615 | eff(%):  2.975 | loglstar:   -inf < -80.981 <    inf | logz: -91.349 +/-  0.291 | dlogz: 29.843 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 896it [02:09, 13.91it/s, bound: 176 | nc: 32 | ncall: 29857 | eff(%):  3.001 | loglstar:   -inf < -78.990 <    inf | logz: -90.047 +/-  0.310 | dlogz: 28.430 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 898it [02:10,  4.05it/s, bound: 179 | nc: 337 | ncall: 30207 | eff(%):  2.973 | loglstar:   -inf < -78.929 <    inf | logz: -89.887 +/-  0.311 | dlogz: 28.240 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 912it [02:12,  8.55it/s, bound: 181 | nc: 17 | ncall: 30573 | eff(%):  2.983 | loglstar:   -inf < -77.468 <    inf | logz: -88.640 +/-  0.317 | dlogz: 26.858 >  0.109] /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 914it [02:12,  9.75it/s, bound: 181 | nc: 18 | ncall: 30596 | eff(%):  2.987 | loglstar:   -inf < -77.412 <    inf | logz: -88.488 +/-  0.317 | dlogz: 26.677 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 918it [02:13,  8.18it/s, bound: 182 | nc: 36 | ncall: 30743 | eff(%):  2.986 | loglstar:   -inf < -77.035 <    inf | logz: -88.197 +/-  0.317 | dlogz: 26.348 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 922it [02:13,  8.83it/s, bound: 183 | nc: 28 | ncall: 30841 | eff(%):  2.990 | loglstar:   -inf < -76.623 <    inf | logz: -87.896 +/-  0.317 | dlogz: 26.016 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 988it [02:19, 11.04it/s, bound: 191 | nc: 8 | ncall: 32145 | eff(%):  3.074 | loglstar:   -inf < -69.955 <    inf | logz: -81.911 +/-  0.328 | dlogz: 23.167 >  0.109]  /tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 994it [02:19, 11.25it/s, bound: 192 | nc: 55 | ncall: 32271 | eff(%):  3.080 | loglstar:   -inf < -69.325 <    inf | logz: -81.390 +/-  0.329 | dlogz: 22.596 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in multiply
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 998it [02:20,  9.32it/s, bound: 193 | nc: 63 | ncall: 32376 | eff(%):  3.083 | loglstar:   -inf < -68.923 <    inf | logz: -81.038 +/-  0.330 | dlogz: 22.200 >  0.109]/tmp/ipykernel_32127/3405905591.py:3: RuntimeWarning: overflow encountered in exp
#   return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))
# 1703it [02:49, 10.07it/s, +100 | bound: 237 | nc: 1 | ncall: 39127 | eff(%):  4.620 | loglstar:   -inf < -48.760 <    inf | logz: -63.450 +/-  0.364 | dlogz:  0.001 >  0.109]

# %%
# Plot a summary of the run.
rfig, raxes = dyplot.runplot(sresults)

# %%
tfig, taxes = dyplot.traceplot(sresults)

# %%
samples = sresults.samples  # samples
weights = np.exp(sresults.logwt - sresults.logz[-1])  # normalized weights

labels = ["A","b","t0","alpha"]

samples_equal = dyfunc.resample_equal(samples, weights)
corner.corner(samples_equal,labels=labels);

# %%
quantiles = [dyfunc.quantile(samps, [0.05, 0.5, 0.95], weights=weights)
             for samps in samples.T]
for q,l in zip(quantiles,labels):
    low,med,up=q
    print(l+"\t=\t"+str(round(med,2))+"\t+"+str(round(up-med,2))+"\t-"+str(round(med-low,2)))
# Out:
# A	=	5.32	+3.63	-1.69
# b	=	10.31	+0.17	-0.24
# t0	=	49.08	+2.75	-1.98
# alpha	=	0.13	+0.05	-0.04

# %%
sresults.summary()
# Out:
# Summary
# =======
# nlive: 100
# niter: 1703
# ncall: 39027
# eff(%):  4.620
# logz: -63.450 +/-  0.428

# %%
# "Static" nested sampling.
sampler = dynesty.NestedSampler(loglike, ptform, ndim,logl_args=[data,'gprofile'],ptform_args=['gprofile'],nlive=100)
sampler.run_nested()
sresults2 = sampler.results
# Out:
# 1723it [01:52, 15.33it/s, +100 | bound: 152 | nc: 1 | ncall: 26520 | eff(%):  6.900 | loglstar:   -inf < -52.417 <    inf | logz: -67.312 +/-  0.363 | dlogz:  0.001 >  0.109]

# %%
tfig, taxes = dyplot.traceplot(sresults2)

# %%
samples = sresults2.samples  # samples
weights = np.exp(sresults2.logwt - sresults2.logz[-1])  # normalized weights

labels = ["A","b","t0","sigmaW"]

samples_equal = dyfunc.resample_equal(samples, weights)
corner.corner(samples_equal,labels=labels);

# %%
sresults2.summary()
# Out:
# Summary
# =======
# nlive: 100
# niter: 1723
# ncall: 26420
# eff(%):  6.900
# logz: -67.312 +/-  0.422

# %%
logevratio  = sresults.logz[-1]-sresults2.logz[-1]

print(logevratio/np.log(10), np.exp(logevratio))
# Out:
# 1.6773977077000983 47.5770716314169

# %%
tgrid=np.linspace(0,100,100)

chosen_samples= samples_equal[np.random.choice(len(samples_equal),size=30)]

for chosen_theta in chosen_samples:

    ygrid =  burst(chosen_theta,tgrid)
    plt.plot(tgrid,ygrid,alpha=0.3,c='gray')
    
plt.errorbar(t,y,yerr=yerr,fmt='o')
plt.xlabel("time")
plt.ylabel("flux")
# Out:
# Text(0, 0.5, 'flux')

# %%
tgrid=np.linspace(0,100,100)
t0_quick=50
A_quick=5
b_quick=10
sigmaW_quick=2


theta_quick= np.array([A_quick,b_quick,t0_quick,sigmaW_quick])
ygrid =  gprofile(theta_quick,tgrid)

plt.errorbar(t,y,yerr=yerr,fmt='o')
plt.xlabel("time")
plt.ylabel("flux")
plt.plot(tgrid,ygrid)
